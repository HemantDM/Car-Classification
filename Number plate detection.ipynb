# %% [markdown]
# ## 0. Install and Import Dependencies
# Reference-https://youtu.be/NApYP_5wlKY

# %%
# !pip install easyocr
# !pip install imutils
# Out:
# Collecting easyocr
#   Downloading easyocr-1.6.2-py3-none-any.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\heman\anaconda3\lib\site-packages (from easyocr) (1.9.1)
# Requirement already satisfied: Pillow in c:\users\heman\anaconda3\lib\site-packages (from easyocr) (9.2.0)
# Collecting python-bidi
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Collecting torchvision>=0.5
#   Downloading torchvision-0.14.0-cp39-cp39-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 5.0 MB/s eta 0:00:00
# Collecting Shapely
#   Downloading Shapely-1.8.5.post1-cp39-cp39-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in c:\users\heman\anaconda3\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: scikit-image in c:\users\heman\anaconda3\lib\site-packages (from easyocr) (0.19.2)
# Collecting pyclipper
#   Downloading pyclipper-1.3.0.post4-cp39-cp39-win_amd64.whl (95 kB)
#      ---------------------------------------- 95.1/95.1 kB 5.7 MB/s eta 0:00:00
# Collecting opencv-python-headless<=4.5.4.60
#   Downloading opencv_python_headless-4.5.4.60-cp39-cp39-win_amd64.whl (35.0 MB)
#      ---------------------------------------- 35.0/35.0 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\heman\anaconda3\lib\site-packages (from easyocr) (1.21.5)
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-win_amd64.whl (313 kB)
#      -------------------------------------- 313.0/313.0 kB 3.9 MB/s eta 0:00:00
# Collecting torch
#   Downloading torch-1.13.0-cp39-cp39-win_amd64.whl (167.2 MB)
#      -------------------------------------- 167.2/167.2 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\heman\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (4.3.0)
# Requirement already satisfied: requests in c:\users\heman\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: six in c:\users\heman\anaconda3\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\heman\anaconda3\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\heman\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: networkx>=2.2 in c:\users\heman\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.8.4)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\heman\anaconda3\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\heman\anaconda3\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\heman\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\heman\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\heman\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\heman\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\heman\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Installing collected packages: pyclipper, ninja, torch, Shapely, python-bidi, opencv-python-headless, torchvision, easyocr
# Successfully installed Shapely-1.8.5.post1 easyocr-1.6.2 ninja-1.11.1 opencv-python-headless-4.5.4.60 pyclipper-1.3.0.post4 python-bidi-0.4.2 torch-1.13.0 torchvision-0.14.0
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25847 sha256=03bad3a4c426705de0ee00f898a4aa4362f6918e6f1170697321cadcfcece3ae
#   Stored in directory: c:\users\heman\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %% [markdown]
# ## 1. Read in Image, Grayscale and Blur

# %%
img = cv2.imread('image3.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 2. Apply filter and find edges for localization

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 3. Find Contours and Apply Mask

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[263, 334]],
#
#        [[264, 363]],
#
#        [[369, 362]],
#
#        [[366, 333]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 4. Use Easy OCR To Read Text

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[0, 2], [107, 2], [107, 31], [0, 31]], 'EBJY. 982]', 0.3741937983327902)]

# %% [markdown]
# ## 5. Render Result

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Reference for morphological operation-https://youtu.be/03B64y9jrF0

# %%
image = Image.open('image3.jpg')
image = image.resize((450,250))
image_arr = np.array(image)
image
# Out:
# <PIL.Image.Image image mode=RGB size=450x250>

# %%
grey = cv2.cvtColor(image_arr,cv2.COLOR_BGR2GRAY)
Image.fromarray(grey)
# Out:
# <PIL.Image.Image image mode=L size=450x250>

# %%
from PIL import Image
blur = cv2.GaussianBlur(grey,(5,5),0)
Image.fromarray(blur)
# Out:
# <PIL.Image.Image image mode=L size=450x250>

# %%
dilated = cv2.dilate(blur,np.ones((3,3)))
Image.fromarray(dilated)
# Out:
# <PIL.Image.Image image mode=L size=450x250>

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2, 2))
closing = cv2.morphologyEx(dilated, cv2.MORPH_CLOSE, kernel) 
Image.fromarray(closing)
# Out:
# <PIL.Image.Image image mode=L size=450x250>

# %%
car_cascade_src = 'cars.xml'
car_cascade = cv2.CascadeClassifier(car_cascade_src)
cars = car_cascade.detectMultiScale(closing, 1.1, 1)

# %%
cnt = 0
for (x,y,w,h) in cars:
  cv2.rectangle(image_arr,(x,y),(x+w,y+h),(255,0,0),2)
  cnt += 1
print(cnt, " cars found")
Image.fromarray(image_arr)
# Out:
# 9  cars found
# <PIL.Image.Image image mode=RGB size=450x250>
